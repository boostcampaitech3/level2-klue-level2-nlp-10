# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../dataset/train/train.csv')

# %%
df.head()
# Out:
#    id                                           sentence  \
# 0   0  〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...
# 1   1  호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으...
# 2   2  K리그2에서 성적 1위를 달리고 있는 광주FC는 지난 26일 한국프로축구연맹으로부터...
# 3   3  균일가 생활용품점 (주)아성다이소(대표 박정부)는 코로나19 바이러스로 어려움을 겪...
# 4   4  1967년 프로 야구 드래프트 1순위로 요미우리 자이언츠에게 입단하면서 등번호는 8...
#
#                                       subject_entity  \
# 0  {'word': '비틀즈', 'start_idx': 24, 'end_idx': 26...
# 1  {'word': '민주평화당', 'start_idx': 19, 'end_idx': ...
# 2  {'word': '광주FC', 'start_idx': 21, 'end_idx': 2...
# 3  {'word': '아성다이소', 'start_idx': 13, 'end_idx': ...
# 4  {'word': '요미우리 자이언츠', 'start_idx': 22, 'end_id...
#
#                                        object_entity  \
# 0  {'word': '조지 해리슨', 'start_idx': 13, 'end_idx':...
# 1  {'word': '대안신당', 'start_idx': 14, 'end_idx': 1...
# 2  {'word': '한국프로축구연맹', 'start_idx': 34, 'end_idx...
# 3  {'word': '박정부', 'start_idx': 22, 'end_idx': 24...
# ...

# %%
df['subject_entity'][0]
# Out:
# "{'word': '비틀즈', 'start_idx': 24, 'end_idx': 26, 'type': 'ORG'}"

# %%
df.shape[0]
# Out:
# 32470

# %%
df.nunique()
# Out:
# id                32470
# sentence          28803
# subject_entity    26340
# object_entity     25704
# label                30
# source                3
# dtype: int64

# %%
test = df

# %%
test[test[['sentence', 'subject_entity', 'object_entity']].duplicated(keep = False)]
# Out:
#           id                                           sentence  \
# 255      255  2010년 10월 15일 전라북도청을 방문한 맹형규 행정안전부 장관은 도내 지자체간...
# 277      277  이날 프로그램 공개에서는 전북영산작법보존회와 김명신‧정상희의 사제동행 판소리, 관악...
# 630      630  배우 마동석, 박정민, 정해인, 염정아, 최성은, 윤경호 씨가 출연하는 영화 '시동...
# 1386    1386  특히, KRI 한국기록원으로부터 2년 연속 공인중개사 최다 합격자 배출 기록을 공식...
# 1721    1721  그러나 곧 이은 총선에서 한나라당이 원내 1당을 차지했고 연정상대였던 자유민주연합은...
# ...      ...                                                ...
# 31786  31786  그러나, 1940년 달라이 라마 14세의 즉위식에 참석한 중화민국은 행정원몽장위원회...
# 31896  31896  이용빈 후보는 전)더불어민주당 광산갑 지역위원장, 전)더불어민주당 정책위원회 부의장...
# 32274  32274         결국 2018년 초에 국민의당은 바른미래당과 민주평화당으로 갈라지고 말았다.
# 32282  32282  박능후 중앙재난안전대책본부 1차장(보건복지부 장관)이 중앙재난안전대책본부 정례브리핑...
# 32299  32299  배우 김병철 씨가 연기하는 정복동은 천리마마트를 망하게 하기 위해 여러 계획을 세우...
#
#                                           subject_entity  \
# 255    {'word': '전라북도청', 'start_idx': 14, 'end_idx': ...
# 277    {'word': '강태환', 'start_idx': 62, 'end_idx': 64...
# ...

# %%
test
# Out:
#           id                                           sentence  \
# 0          0  〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...
# 1          1  호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으...
# 2          2  K리그2에서 성적 1위를 달리고 있는 광주FC는 지난 26일 한국프로축구연맹으로부터...
# 3          3  균일가 생활용품점 (주)아성다이소(대표 박정부)는 코로나19 바이러스로 어려움을 겪...
# 4          4  1967년 프로 야구 드래프트 1순위로 요미우리 자이언츠에게 입단하면서 등번호는 8...
# ...      ...                                                ...
# 32465  32465  한국당은 7일 오전 9시부터 오후 5시까지 진행된 원내대표 및 정책위의장 후보자 등...
# 32466  32466  법포는 다시 최시형, 서병학, 손병희 직계인 북접과 다시 서장옥, 전봉준, 김개남을...
# 32467  32467  완도군(군수 신우철)이 국토교통부에서 실시한 '2019 교통문화지수 실태조사'에서 ...
# 32468  32468  중앙일보, JTBC 회장을 지낸 이후 중앙홀딩스 회장, 재단법인 한반도평화만들기 이...
# 32469  32469  화순군(군수 구충곤)은 17일 동면의 이장 20여 명이 코로나 19 예방을 위해 버...
#
#                                           subject_entity  \
# 0      {'word': '비틀즈', 'start_idx': 24, 'end_idx': 26...
# 1      {'word': '민주평화당', 'start_idx': 19, 'end_idx': ...
# ...

# %%
test = test.drop_duplicates(['sentence', 'subject_entity', 'object_entity'], keep='first')
test
# Out:
#           id                                           sentence  \
# 0          0  〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...
# 1          1  호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으...
# 2          2  K리그2에서 성적 1위를 달리고 있는 광주FC는 지난 26일 한국프로축구연맹으로부터...
# 3          3  균일가 생활용품점 (주)아성다이소(대표 박정부)는 코로나19 바이러스로 어려움을 겪...
# 4          4  1967년 프로 야구 드래프트 1순위로 요미우리 자이언츠에게 입단하면서 등번호는 8...
# ...      ...                                                ...
# 32465  32465  한국당은 7일 오전 9시부터 오후 5시까지 진행된 원내대표 및 정책위의장 후보자 등...
# 32466  32466  법포는 다시 최시형, 서병학, 손병희 직계인 북접과 다시 서장옥, 전봉준, 김개남을...
# 32467  32467  완도군(군수 신우철)이 국토교통부에서 실시한 '2019 교통문화지수 실태조사'에서 ...
# 32468  32468  중앙일보, JTBC 회장을 지낸 이후 중앙홀딩스 회장, 재단법인 한반도평화만들기 이...
# 32469  32469  화순군(군수 구충곤)은 17일 동면의 이장 20여 명이 코로나 19 예방을 위해 버...
#
#                                           subject_entity  \
# 0      {'word': '비틀즈', 'start_idx': 24, 'end_idx': 26...
# 1      {'word': '민주평화당', 'start_idx': 19, 'end_idx': ...
# ...

# %%
test[test[['sentence', 'subject_entity', 'object_entity']].duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [id, sentence, subject_entity, object_entity, label, source]
# Index: []

# %%
test
# Out:
#           id                                           sentence  \
# 0          0  〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...
# 1          1  호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으...
# 2          2  K리그2에서 성적 1위를 달리고 있는 광주FC는 지난 26일 한국프로축구연맹으로부터...
# 3          3  균일가 생활용품점 (주)아성다이소(대표 박정부)는 코로나19 바이러스로 어려움을 겪...
# 4          4  1967년 프로 야구 드래프트 1순위로 요미우리 자이언츠에게 입단하면서 등번호는 8...
# ...      ...                                                ...
# 32465  32465  한국당은 7일 오전 9시부터 오후 5시까지 진행된 원내대표 및 정책위의장 후보자 등...
# 32466  32466  법포는 다시 최시형, 서병학, 손병희 직계인 북접과 다시 서장옥, 전봉준, 김개남을...
# 32467  32467  완도군(군수 신우철)이 국토교통부에서 실시한 '2019 교통문화지수 실태조사'에서 ...
# 32468  32468  중앙일보, JTBC 회장을 지낸 이후 중앙홀딩스 회장, 재단법인 한반도평화만들기 이...
# 32469  32469  화순군(군수 구충곤)은 17일 동면의 이장 20여 명이 코로나 19 예방을 위해 버...
#
#                                           subject_entity  \
# 0      {'word': '비틀즈', 'start_idx': 24, 'end_idx': 26...
# 1      {'word': '민주평화당', 'start_idx': 19, 'end_idx': ...
# ...

# %%
test.iloc[32282]
# Out:
# id                                                            32329
# sentence          순천시에서 관리하고 있는 13개 사회보장급여(국민기초, 한부모, 장애연금, 기초연금...
# subject_entity    {'word': '순천시', 'start_idx': 0, 'end_idx': 2, ...
# object_entity     {'word': '13개', 'start_idx': 14, 'end_idx': 16...
# label                                                   no_relation
# source                                                     wikitree
# Name: 32329, dtype: object

# %%
test[test['id'] == 20757]
# 중복되는 문장들 발견
# Out:
#           id                                           sentence  \
# 20757  20757  박능후 중앙재난안전대책본부 1차장(보건복지부 장관)이 중앙재난안전대책본부 회의를 주...
#
#                                           subject_entity  \
# 20757  {'word': '박능후', 'start_idx': 0, 'end_idx': 2, ...
#
#                                            object_entity      label  \
# 20757  {'word': '보건복지부 장관', 'start_idx': 19, 'end_idx...  per:title
#
#                 source
# 20757  policy_briefing

# %%
test[test['id'] == 10468]
# Out:
#           id                                           sentence  \
# 10468  10468  박능후 중앙재난안전대책본부 1차장(보건복지부 장관)이 중앙재난안전대책본부 정례브리핑...
#
#                                           subject_entity  \
# 10468  {'word': '박능후', 'start_idx': 0, 'end_idx': 2, ...
#
#                                            object_entity      label  \
# 10468  {'word': '보건복지부 장관', 'start_idx': 19, 'end_idx...  per:title
#
#                 source
# 10468  policy_briefing

# %%
for i, j in dict(test[test['id'] == 10468]).items():
    print(f'{i}, {j}')
# Out:
# id, 10468    10468
# Name: id, dtype: int64
# sentence, 10468    박능후 중앙재난안전대책본부 1차장(보건복지부 장관)이 중앙재난안전대책본부 정례브리핑...
# Name: sentence, dtype: object
# subject_entity, 10468    {'word': '박능후', 'start_idx': 0, 'end_idx': 2, ...
# Name: subject_entity, dtype: object
# object_entity, 10468    {'word': '보건복지부 장관', 'start_idx': 19, 'end_idx...
# Name: object_entity, dtype: object
# label, 10468    per:title
# Name: label, dtype: object
# source, 10468    policy_briefing
# Name: source, dtype: object

# %%
print(test[test['id'] == 10468]['object_entity'])
# Out:
# 10468    {'word': '보건복지부 장관', 'start_idx': 19, 'end_idx...
# Name: object_entity, dtype: object

# %%
test[test['id'] == 10468]['object_entity']
# Out:
# 10468    {'word': '보건복지부 장관', 'start_idx': 19, 'end_idx...
# Name: object_entity, dtype: object

# %%
subj_type = []
obj_type = []

for i in range(test.shape[0]):
    subj_type.append((eval(test['subject_entity'].iloc[i]))["type"])
    obj_type.append((eval(test['object_entity'].iloc[i]))["type"])
    
    
test['subj_type'] = subj_type
test['obj_type'] = obj_type

# subj_type과 obj_type 칼럼 추가
# Out:
# <ipython-input-78-d13335ebc6cc>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['subj_type'] = subj_type
# <ipython-input-78-d13335ebc6cc>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['obj_type'] = obj_type

# %%
test
# Out:
#           id                                           sentence  \
# 0          0  〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...
# 1          1  호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으...
# 2          2  K리그2에서 성적 1위를 달리고 있는 광주FC는 지난 26일 한국프로축구연맹으로부터...
# 3          3  균일가 생활용품점 (주)아성다이소(대표 박정부)는 코로나19 바이러스로 어려움을 겪...
# 4          4  1967년 프로 야구 드래프트 1순위로 요미우리 자이언츠에게 입단하면서 등번호는 8...
# ...      ...                                                ...
# 32465  32465  한국당은 7일 오전 9시부터 오후 5시까지 진행된 원내대표 및 정책위의장 후보자 등...
# 32466  32466  법포는 다시 최시형, 서병학, 손병희 직계인 북접과 다시 서장옥, 전봉준, 김개남을...
# 32467  32467  완도군(군수 신우철)이 국토교통부에서 실시한 '2019 교통문화지수 실태조사'에서 ...
# 32468  32468  중앙일보, JTBC 회장을 지낸 이후 중앙홀딩스 회장, 재단법인 한반도평화만들기 이...
# 32469  32469  화순군(군수 구충곤)은 17일 동면의 이장 20여 명이 코로나 19 예방을 위해 버...
#
#                                           subject_entity  \
# 0      {'word': '비틀즈', 'start_idx': 24, 'end_idx': 26...
# 1      {'word': '민주평화당', 'start_idx': 19, 'end_idx': ...
# ...

# %%
label_info = {'no_relation': 0, 'org:top_members/employees': 1, 'org:members': 2, 'org:product': 3, 'per:title': 4, 'org:alternate_names': 5, 'per:employee_of': 6, 'org:place_of_headquarters': 7, 'per:product': 8, 'org:number_of_employees/members': 9, 'per:children': 10, 'per:place_of_residence': 11, 'per:alternate_names': 12, 'per:other_family': 13, 'per:colleagues': 14, 'per:origin': 15, 'per:siblings': 16, 'per:spouse': 17, 'org:founded': 18, 'org:political/religious_affiliation': 19, 'org:member_of': 20, 'per:parents': 21, 'org:dissolved': 22, 'per:schools_attended': 23, 'per:date_of_death': 24, 'per:date_of_birth': 25, 'per:place_of_birth': 26, 'per:place_of_death': 27, 'org:founded_by': 28, 'per:religion': 29}

# %%
label_num_arr = []

for i in range(test.shape[0]):
    label_num_arr.append(label_info[test['label'].iloc[i]])
        
test['label_num'] = label_num_arr

# 나중에 데이터 교정 작업을 위해 라벨넘버 칼럼 추가

# %%
test[:50]
# Out:
#     id                                           sentence  \
# 0    0  〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...
# 1    1  호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으...
# 2    2  K리그2에서 성적 1위를 달리고 있는 광주FC는 지난 26일 한국프로축구연맹으로부터...
# 3    3  균일가 생활용품점 (주)아성다이소(대표 박정부)는 코로나19 바이러스로 어려움을 겪...
# 4    4  1967년 프로 야구 드래프트 1순위로 요미우리 자이언츠에게 입단하면서 등번호는 8...
# 5    5  : 유엔, 유럽 의회, 북대서양 조약 기구 (NATO), 국제이주기구, 세계 보건 ...
# 6    6  그에 따라 나폴리와 계약을 연장한 마라도나는 1989년 팀을 UEFA컵 정상으로 인...
# 7    7  박용오(朴容旿, 1937년 4월 29일(음력 3월 19일)(음력 3월 19일) ~ ...
# 8    8  중공군에게 온전히 대항할 수 없을 정도로 약해진 국민당은 타이베이로 수도를 옮기는 ...
# 9    9  특히 김동연 전 경제부총리를 비롯한 김두관 국회의원, 안규백 국회의원, 김종민 국회...
# 10  10        하비에르 파스토레는 아르헨티나 클럽 타예레스의 유소년팀에서 축구를 시작하였다.
# 11  11  이른바 'Z세대'로 불리는 1990년대 중반 이후 태어난 세대에게 대표 아이콘으로 ...
# 12  12  2009년 9월, 미국 프로 야구 필라델피아 필리스 소속의 야구 선수 박찬호는 《M...
# 13  13  뉴질랜드 1차산업부 생물보안 대변인 캐서린 더시 박사는 과일파리를 잡기 위해 오클랜...
# 14  14  조토 디 본도네, 마사초, 피에로 델라 프란체스카, 도메니코 기를란다요, 페루지노,...
# ...

# %%
st_set = set(subj_type)
ob_set = set(obj_type)

# %%
st_set
# Out:
# {'ORG', 'PER'}

# %%
ob_set
# Out:
# {'DAT', 'LOC', 'NOH', 'ORG', 'PER', 'POH'}

# %%
test[test['obj_type'] == 'POH'][:20]
# Out:
#       id                                           sentence  \
# 11    11  이른바 'Z세대'로 불리는 1990년대 중반 이후 태어난 세대에게 대표 아이콘으로 ...
# 24    24  FA로 친정 팀에 돌아온 중견수 이택근과 1루수로 정착한 박병호와 함께 클린업 트리...
# 30    30  미국 정부는 1942년 2월 24일 전 세계의 청취자를 대상으로 태평양 전쟁의 전쟁...
# 38    38  광주국악상설공연이 세계수영선수권대회 기간동안 연이어 매진을 기록하며 광주 대표 문화...
# 41    41  이 캐릭터가 작가 스탠 리와 만화가 잭 커비가 만든 "" 에서 캡틴 아메리카의 전쟁...
# 48    48  후기 낭만적 음악의 화성조직이나 색채적인 오케스트라의 사용법이라든가 그러한 개개의 ...
# 50    50  1924년 11월 26일에는 정부 형태를 군주제에서 인민 공화제로 고쳐 국호를 몽골...
# 52    52  (KIA 내야수 그, 투수 이동현, 외야수 김경언 ↔ 한화 투수 안영명, 박성호, ...
# 57    57  2018년 4월 11일 정의당의 추혜선 대변인은 "김기식의 해명과 청와대의 입장 발...
# 58    58  멘토로 뮤지컬 배우 엄기준, 차지연, 한지상, 마이클리와 무대연출가 이지나 씨가 출...
# 69    69  칸트는 미(美)란 숭고함이다라고 주장하였는데 그의 이러한 주장은 윌리엄 터너(Jos...
# 70    70  파나소닉이 대만 누보톤 테크놀로지에 반도체 부문 주식을 매각한다고 니혼게이자이신문이...
# 71    71  디에고 베날리오가 현재 국가대표팀의 주전 골키퍼를 맡고 있으며, 그와 바젤의 얀 조...
# 76    76  1727년(옹정 5년), 옹정제는 자신의 심복이자 과거 사천 순무로 그 곳 사정을 ...
# 83    83  진도군은 진도개를 보기 위해 찾아온 관람객들에게 더욱 흥미롭고 즐거움을 선사하기 위...
# ...
